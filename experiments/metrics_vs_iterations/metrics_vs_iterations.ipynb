# %% [markdown]
# ## Metrica acc_at_least_one y acc_both vs interations

# %% [markdown]
# ### Mnist

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../..")))
from experiments import load
from CROP_models.crop import crop
import matplotlib.pyplot as plt
#dataset="fashion"
dataset="mnist"

data = load.data(dataset=dataset)
predictor = load.predictor(dataset=dataset)
x_train = data["x_train"]
x_test = data["x_test"]
x_val = data["x_val"]
y_train = data["y_train"]
y_test = data["y_test"]
y_val = data["y_val"]
x_train_1 = data["x_train_1"]
y_train_1 = data["y_train_1"]  
x_test_1  =data["x_test_1"]
y_test_1  =data["y_test_1"]


model = load.cvae(lat=256, inter=512,dataset=dataset)

crop_f0 = crop(model,predictor=predictor,data=data)

iterations=400

metrics  = crop_f0.unmix(
    x_test[:],
    x_test_1[:],
    y_test[:],
    y_test_1[:],
    iterations=iterations,
    curve=True
)


plt.plot(metrics["acc_at_least_one_plot"], label=f"al menos uno ( {metrics["acc_at_least_one_plot"][-1] } )")
plt.plot(metrics["acc_both_plot"], label=f"ambos ({metrics["acc_both_plot"][-1]})")
plt.grid()
plt.title("Accuracy")
plt.xlabel("iterations")
plt.ylabel("acc")
plt.legend()
plt.savefig("acc_at_leat_one_and_both_mnist_default.png")
plt.show()
# Out:
# 2025-10-07 01:04:00.331981: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-07 01:04:00.886943: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-07 01:04:01.265234: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759809841.693448  321638 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759809841.811930  321638 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759809842.783997  321638 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759809842.784071  321638 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759809842.784080  321638 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759809842.784086  321638 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-07 01:04:02.920496: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Usando mnist como dataset
# E0000 00:00:1759809848.600053  321638 cuda_executor.cc:1228] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1759809848.602246  321638 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ### mnist opt

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../..")))
from experiments import load
from CROP_models.crop import crop
import matplotlib.pyplot as plt
#dataset="fashion"
dataset="mnist"

data = load.data(dataset=dataset)
predictor = load.predictor(dataset=dataset)
x_train = data["x_train"]
x_test = data["x_test"]
x_val = data["x_val"]
y_train = data["y_train"]
y_test = data["y_test"]
y_val = data["y_val"]
x_train_1 = data["x_train_1"]
y_train_1 = data["y_train_1"]  
x_test_1  =data["x_test_1"]
y_test_1  =data["y_test_1"]


model = load.cvae(lat=256, inter=512,dataset=dataset)

crop_f0 = crop(model,predictor=predictor,
               data=data,bias=0.2562,slope=10.0067 ,beta=1)


iterations=400

metrics  = crop_f0.unmix(
    x_test[:],
    x_test_1[:],
    y_test[:],
    y_test_1[:],
    iterations=iterations,
    curve=True
)


plt.plot(metrics["acc_at_least_one_plot"], label=f"al menos uno ( {metrics["acc_at_least_one_plot"][-1] } )")
plt.plot(metrics["acc_both_plot"], label=f"ambos ({metrics["acc_both_plot"][-1]})")
plt.grid()
plt.title("Accuracy")
plt.xlabel("iterations")
plt.ylabel("acc")
plt.legend()
plt.savefig("acc_at_leat_one_and_both_mnist_opt.png")
plt.show()
# Out:
# Usando mnist como dataset

# %% [markdown]
# ### Fashion

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../..")))
from experiments import load
from CROP_models.crop import crop
import matplotlib.pyplot as plt
dataset="fashion"
#dataset="mnist"

data = load.data(dataset=dataset)
predictor = load.predictor(dataset=dataset)
x_train = data["x_train"]
x_test = data["x_test"]
x_val = data["x_val"]
y_train = data["y_train"]
y_test = data["y_test"]
y_val = data["y_val"]
x_train_1 = data["x_train_1"]
y_train_1 = data["y_train_1"]  
x_test_1  =data["x_test_1"]
y_test_1  =data["y_test_1"]


model = load.cvae(lat=256, inter=512,dataset=dataset)

crop_f0 = crop(model,predictor=predictor,data=data)

# crop_f0 = crop(model,predictor=predictor,
#                data=data,bias=0.18495822150909808,slope= 18.248678323921897,beta=1)



iterations=400

metrics  = crop_f0.unmix(
    x_test[:],
    x_test_1[:],
    y_test[:],
    y_test_1[:],
    iterations=iterations,
    curve=True
)


plt.plot(metrics["acc_at_least_one_plot"], label=f"al menos uno ( {metrics["acc_at_least_one_plot"][-1] } )")
plt.plot(metrics["acc_both_plot"], label=f"ambos ({metrics["acc_both_plot"][-1]})")
plt.grid()
plt.title("Accuracy")
plt.xlabel("iterations")
plt.ylabel("acc")
plt.legend()
plt.savefig("acc_at_leat_one_and_both_fmnist_default.png")
plt.show()
# Out:
# Usando fashion como dataset

# %% [markdown]
# ### fashion opt

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../..")))
from experiments import load
from CROP_models.crop import crop
import matplotlib.pyplot as plt
dataset="fashion"
#dataset="mnist"

data = load.data(dataset=dataset)
predictor = load.predictor(dataset=dataset)
x_train = data["x_train"]
x_test = data["x_test"]
x_val = data["x_val"]
y_train = data["y_train"]
y_test = data["y_test"]
y_val = data["y_val"]
x_train_1 = data["x_train_1"]
y_train_1 = data["y_train_1"]  
x_test_1  =data["x_test_1"]
y_test_1  =data["y_test_1"]


model = load.cvae(lat=256, inter=512,dataset=dataset)

crop_f0 = crop(model,predictor=predictor,
               data=data,bias=0.18495822150909808,slope= 18.248678323921897,beta=1)



iterations=400

metrics  = crop_f0.unmix(
    x_test[:],
    x_test_1[:],
    y_test[:],
    y_test_1[:],
    iterations=iterations,
    curve=True
)


plt.plot(metrics["acc_at_least_one_plot"], label=f"al menos uno ( {metrics["acc_at_least_one_plot"][-1] } )")
plt.plot(metrics["acc_both_plot"], label=f"ambos ({metrics["acc_both_plot"][-1]})")
plt.grid()
plt.title("Accuracy")
plt.xlabel("iterations")
plt.ylabel("acc")
plt.legend()
plt.savefig("acc_at_leat_one_and_both_fmnist_opt.png")
plt.show()
# Out:
# Usando fashion como dataset

# %% [markdown]
# ### CROP-2

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../..")))
from experiments import load
from CROP_models.crop import crop
import matplotlib.pyplot as plt
dataset="fashion"
#dataset="mnist"

data = load.data(dataset=dataset)
predictor = load.predictor(dataset=dataset)
x_train = data["x_train"]
x_test = data["x_test"]
x_val = data["x_val"]
y_train = data["y_train"]
y_test = data["y_test"]
y_val = data["y_val"]
x_train_1 = data["x_train_1"]
y_train_1 = data["y_train_1"]  
x_test_1  =data["x_test_1"]
y_test_1  =data["y_test_1"]


model = load.cvae(lat=256, inter=512, dataset=dataset)

crop_f0 = crop(model,predictor=predictor,
               data=data,bias=bias,slope= 18.248678323921897,beta=1)


iterations=400

metrics  = crop_f0.unmix(
    x_test[:],
    x_test_1[:],
    y_test[:],
    y_test_1[:],
    iterations=iterations,
    curve=True
)


plt.plot(metrics["acc_at_least_one_plot"], label=f"al menos uno ( {metrics["acc_at_least_one_plot"][-1] } )")
plt.plot(metrics["acc_both_plot"], label=f"ambos ({metrics["acc_both_plot"][-1]})")
plt.grid()
plt.title("Accuracy")
plt.xlabel("iterations")
plt.ylabel("acc")
plt.legend()
plt.savefig("acc_at_leat_one_and_both_fmnist_opt_crop_2.png")
plt.show()
# Out:
# Usando fashion como dataset

# %% [markdown]
# ### Modelos dentro de crop2

# %%
import os
import sys
import numpy as np
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../..")))
from experiments import load
from CROP_models.crop2_model import Crop2
import matplotlib.pyplot as plt
dataset="fashion"
#dataset="mnist"

data = load.data(dataset=dataset)
predictor = load.predictor(dataset=dataset)
x_train = data["x_train"]
x_test = data["x_test"]
x_val = data["x_val"]
y_train = data["y_train"]
y_test = data["y_test"]
y_val = data["y_val"]
x_train_1 = data["x_train_1"]
y_train_1 = data["y_train_1"]  
x_test_1  =data["x_test_1"]
y_test_1  =data["y_test_1"]



model = load.cvae(lat=64, inter=128,dataset=dataset)


crop_f0 = Crop2(model,predictor=predictor,
               data=data,bias=bias,slope= 18.248678323921897,beta=1)


iterations = 10

metrics = crop_f0.get_curve(
    x_test[:],
    x_test_1[:],
    y_test[:],
    y_test_1[:],
    iterations=iterations,
)

plt.plot(metrics["acc_at_least_one_plot"], label=f"al menos uno ( {np.max(metrics["acc_at_least_one_plot"])} )")
plt.plot(metrics["acc_both_plot"], label=f"ambos ({ np.max(metrics["acc_both_plot"])})")
plt.grid()
plt.title("Accuracy")
plt.xlabel("iterations")
plt.ylabel("acc")
plt.legend()
plt.savefig("acc_at_leat_one_and_both_fmnist_opt_crop_2_base.png")
plt.show()
# Out:
# Usando fashion como dataset

# %% [markdown]
# Comparación de distitnos cvaes

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../..")))
from experiments import load
from CROP_models.crop2_model import Crop2
import matplotlib.pyplot as plt
dataset="fashion"
#dataset="mnist"

data = load.data(dataset=dataset)
predictor = load.predictor(dataset=dataset)
x_train = data["x_train"]
x_test = data["x_test"]
x_val = data["x_val"]
y_train = data["y_train"]
y_test = data["y_test"]
y_val = data["y_val"]
x_train_1 = data["x_train_1"]
y_train_1 = data["y_train_1"]  
x_test_1  =data["x_test_1"]
y_test_1  =data["y_test_1"]


model = load.cvae(lat=256, inter=512, dataset=dataset)

# optim 1
bias = 0.18495822150909808
slope = 18.248678323921897



crop_f0 = Crop2(model,predictor=predictor,
               data=data,bias=bias,slope= slope,beta=1)


iterations=400

metrics  = crop_f0.get_curve(
    x_test[:],
    x_test_1[:],
    y_test[:],
    y_test_1[:],
    iterations=iterations,
)


#plt.plot(metrics["acc_at_least_one_plot"], label=f"al_menos_uno_lat_256_inter_512 ( {np.max(metrics["acc_at_least_one_plot"]) } )")
plt.plot(metrics["acc_both_plot"], label=f"ambos_256_inter_512  ({np.max(metrics["acc_both_plot"])})")
plt.grid()
plt.title("Accuracy")
plt.xlabel("iterations")
plt.ylabel("acc")


model = load.cvae(lat=256, inter=1024, dataset=dataset)

crop_f0 = Crop2(model,predictor=predictor,
               data=data,bias=bias,slope= slope,beta=1)



metrics  = crop_f0.get_curve(
    x_test[:],
    x_test_1[:],
    y_test[:],
    y_test_1[:],
    iterations=iterations,
)

#plt.plot(metrics["acc_at_least_one_plot"], label=f"al_menos_uno_lat_256_inter_1024 ( {np.max(metrics["acc_at_least_one_plot"]) } )")
plt.plot(metrics["acc_both_plot"], label=f"ambos_256_inter_1024 ({np.max(metrics["acc_both_plot"])})")


model = load.cvae(lat=128, inter=256, dataset=dataset)

crop_f0 = Crop2(model,predictor=predictor,
               data=data,bias=bias,slope= slope,beta=1)



metrics  = crop_f0.get_curve(
    x_test[:],
    x_test_1[:],
    y_test[:],
    y_test_1[:],
    iterations=iterations,
)

#plt.plot(metrics["acc_at_least_one_plot"], label=f"al_menos_uno_lat_128_inter_256( {np.max(metrics["acc_at_least_one_plot"]) } )")
plt.plot(metrics["acc_both_plot"], label=f"ambos_128_inter_256( ({np.max(metrics["acc_both_plot"])})")

model = load.cvae(lat=64, inter=128, dataset=dataset)

crop_f0 = Crop2(model,predictor=predictor,
              data=data,bias=bias,slope= slope,beta=1)

metrics  = crop_f0.get_curve(
    x_test[:],
    x_test_1[:],
    y_test[:],
    y_test_1[:],
    iterations=iterations,
)
plt.plot(metrics["acc_both_plot"], label=f"ambos_64_inter_128 {np.max(metrics["acc_both_plot"])}")

plt.legend()
plt.savefig("acc_at_leat_one_and_both_fmnist_opt_crop_2_base_optim.png")
plt.show()
# Out:
# Usando fashion como dataset

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../..")))
from experiments import load
from CROP_models.crop2_model import Crop2
import matplotlib.pyplot as plt
dataset="fashion"
#dataset="mnist"

data = load.data(dataset=dataset)
predictor = load.predictor(dataset=dataset)
x_train = data["x_train"]
x_test = data["x_test"]
x_val = data["x_val"]
y_train = data["y_train"]
y_test = data["y_test"]
y_val = data["y_val"]
x_train_1 = data["x_train_1"]
y_train_1 = data["y_train_1"]  
x_test_1  =data["x_test_1"]
y_test_1  =data["y_test_1"]


model = load.cvae(lat=256, inter=512, dataset=dataset)

# optim 1
bias = 0.18495822150909808
slope = 18.248678323921897



crop_f0 = Crop2(model,predictor=predictor,
               data=data,bias=bias,slope= slope,beta=1)


iterations=100

metrics  = crop_f0.get_curve(
    x_test[:],
    x_test_1[:],
    y_test[:],
    y_test_1[:],
    iterations=iterations,
)


#plt.plot(metrics["acc_at_least_one_plot"], label=f"al_menos_uno_lat_256_inter_512 ( {np.max(metrics["acc_at_least_one_plot"]) } )")
plt.plot(metrics["acc_both_plot"], label=f"ambos_256_inter_512  ({np.max(metrics["acc_both_plot"])})")
plt.grid()
plt.title("Accuracy")
plt.xlabel("iterations")
plt.ylabel("acc")


model = load.cvae(lat=128, inter=512, dataset=dataset)

crop_f0 = Crop2(model,predictor=predictor,
               data=data,bias=bias,slope= slope,beta=1)



metrics  = crop_f0.get_curve(
    x_test[:],
    x_test_1[:],
    y_test[:],
    y_test_1[:],
    iterations=iterations,
)

#plt.plot(metrics["acc_at_least_one_plot"], label=f"al_menos_uno_lat_256_inter_1024 ( {np.max(metrics["acc_at_least_one_plot"]) } )")
plt.plot(metrics["acc_both_plot"], label=f"ambos_128_inter_512 ({np.max(metrics["acc_both_plot"])})")


model = load.cvae(lat=64, inter=256, dataset=dataset)

crop_f0 = Crop2(model,predictor=predictor,
               data=data,bias=bias,slope= slope,beta=1)



metrics  = crop_f0.get_curve(
    x_test[:],
    x_test_1[:],
    y_test[:],
    y_test_1[:],
    iterations=iterations,
)

#plt.plot(metrics["acc_at_least_one_plot"], label=f"al_menos_uno_lat_128_inter_256( {np.max(metrics["acc_at_least_one_plot"]) } )")
plt.plot(metrics["acc_both_plot"], label=f"ambos_64_inter_256( ({np.max(metrics["acc_both_plot"])})")

model = load.cvae(lat=2, inter=128, dataset=dataset)

crop_f0 = Crop2(model,predictor=predictor,
              data=data,bias=bias,slope= slope,beta=1)

metrics  = crop_f0.get_curve(
    x_test[:],
    x_test_1[:],
    y_test[:],
    y_test_1[:],
    iterations=iterations,
)
plt.plot(metrics["acc_both_plot"], label=f"ambos_2_inter_128 {np.max(metrics["acc_both_plot"])}")

plt.legend()
plt.savefig("acc_at_leat_one_and_both_fmnist_opt_crop_2_base_optim.png")
plt.show()
# Out:
# Usando fashion como dataset
