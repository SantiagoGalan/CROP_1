# %% [markdown]
# ### Reconstruccion de una imagen a modo de prueba

# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../..")))
from project.loader import load
from project.metrics.metrics import Metrics 
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
dataset = "mnist"

data = load.data(dataset=dataset)

models = load.all_models(dataset=dataset)

x_test = data["x_test"]
y_test = data["y_test"]

resultados = []
metric = "ssim"
idx = 0
n_pictures = 1
errores = []  # lista de filas, cada fila = un modelo

for m in models:

    errores_modelo = []   # fila de errores para este modelo

    for idx in range(n_pictures):
        x = x_test[idx : idx + 1]  # (1, 28, 28)
        y = y_test[idx : idx + 1]  # (1, 10)

        # Codificar
        z_mean, _, z = m.encoder.predict([x, y], verbose=0)

        # Decodificar
        x_recon = m.decoder.predict([z, y], verbose=0)

        # Calcular error
        if metric == "psnr":
             error_value = Metrics.psnr_grayscale(target=x, preds=x_recon)
        else:
            error_value = Metrics.ssim_grayscale(target=x, preds=x_recon)   
           
        errores_modelo.append(error_value)

    errores.append(errores_modelo)
    
    x_pic = tf.reshape(x, (28, 28))
    x_recon = tf.reshape(x_recon, (28, 28))


    plt.title(f"Imganes{m.name}")
    plt.xlabel("Modelo")
    plt.imshow(x_pic, cmap="gray")
    # Usar nombres como ticks
    plt.tight_layout()
    plt.show()
# Out:
# 2026-02-25 14:28:26.434016: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-25 14:28:26.437774: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-25 14:28:26.474488: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-25 14:28:26.498561: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772040506.538845   96678 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772040506.547518   96678 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772040506.600727   96678 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772040506.600743   96678 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772040506.600744   96678 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772040506.600745   96678 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-25 14:28:26.607180: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import sys
#       3 sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../..")))
# ----> 4 from project.loader import load
#       5 from project.metrics.metrics import Metrics
#       6 import tensorflow as tf
#
# File ~/Desktop/tesis/CROP_1/project/loader/__init__.py:1
# ----> 1 from .load import Loader
#       3 __all__ = ["Loader"]
#
# File ~/Desktop/tesis/CROP_1/project/loader/load.py:7
#       5 from project.custom_layers.reshapeLayer import ReshapeLayer
#       6 from project.data.get_data import get_mnist_data
# ----> 7 from project.models_definitions.cvae import CVAE
#      10 class Loader:
#      11     # ---------- paths (class-level) ----------
#      13     BASE_DIR = os.path.abspath(
#      14         os.path.join(os.path.dirname(__file__), "..", "trained_models")
#      15     )
#
# File ~/Desktop/tesis/CROP_1/project/models_definitions/__init__.py:4
#       2 from .decoder import Decoder
#       3 from .cvae import CVAE
# ----> 4 from .predictor import Predictor
#       6 __all__ = ["Encoder", "Decoder", "CVAE","Predictor"]
#
# File ~/Desktop/tesis/CROP_1/project/models_definitions/predictor.py:3
#       1 import tensorflow as tf
#       2 from keras.layers import Dense, Conv2D, BatchNormalization, Dropout, Flatten
# ----> 3 from custom_layers.reshapeLayer import ReshapeLayer
#       6 class Predictor(tf.keras.Model):
#       7     def __init__(
#       8         self,
#       9         image_size=28,
#    (...)     13         **kwargs,
#      14     ):
#
# ModuleNotFoundError: No module named 'custom_layers'
